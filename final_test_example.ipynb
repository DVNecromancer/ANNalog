# %%
from model import vocabulary
import torch
import torch.nn as nn
import torch.optim as optim
from collections import defaultdict

from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pad_sequence

from collections import Counter
from torchtext.vocab import vocab
from torchtext.data import get_tokenizer

from torchtext.legacy.data import Field, BucketIterator
from model.seq2seq_dataset import SMILESDataset
import numpy as np

import random
import math
import time
import tqdm

from model import seq2seq_attention

from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem import DataStructs
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from model import multi_gen_test
import pickle

# %%
# Load the model and dataset
SRC = Field(tokenize=vocabulary.SMILESTokenizer().tokenize, 
            init_token='<sos>', 
            eos_token='<eos>', 
            lower=False, 
            batch_first=True)
TRG = Field(tokenize=vocabulary.SMILESTokenizer().tokenize, 
            init_token='<sos>', 
            eos_token='<eos>', 
            lower=False, 
            batch_first=True)

# Load vocabulary
src_vocab_path = '/home/wei/Desktop/Similarity/chembl33_dataset/vocab_pkls/stereo_experiment_vocab.pkl'
trg_vocab_path = '/home/wei/Desktop/Similarity/chembl33_dataset/vocab_pkls/stereo_experiment_vocab.pkl'
with open(src_vocab_path, 'rb') as f:
    SRC.vocab = pickle.load(f)
with open(trg_vocab_path, 'rb') as f:
    TRG.vocab = pickle.load(f)

# Model parameters
INPUT_DIM = len(SRC.vocab)
OUTPUT_DIM = len(TRG.vocab)
HID_DIM = 256
ENC_LAYERS = 3
DEC_LAYERS = 3
ENC_HEADS = 8
DEC_HEADS = 8
ENC_PF_DIM = 512
DEC_PF_DIM = 512
ENC_DROPOUT = 0.1
DEC_DROPOUT = 0.1
max_length = 102

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

enc = seq2seq_attention.Encoder(INPUT_DIM, HID_DIM, ENC_LAYERS, ENC_HEADS, ENC_PF_DIM, ENC_DROPOUT, device, max_length)
dec = seq2seq_attention.Decoder(OUTPUT_DIM, HID_DIM, DEC_LAYERS, DEC_HEADS, DEC_PF_DIM, DEC_DROPOUT, device, max_length)

SRC_PAD_IDX = SRC.vocab.stoi[SRC.pad_token]
TRG_PAD_IDX = TRG.vocab.stoi[TRG.pad_token]
model = seq2seq_attention.Seq2Seq(enc, dec, SRC_PAD_IDX, TRG_PAD_IDX, device).to(device)

# Load pre-trained weights
model.load_state_dict(torch.load('/home/wei/Desktop/Similarity/self_seq2seq_try/ckpts/chembl33/shuffled_filtered_stereo/att_130eps.pt'))
model.eval()
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (tok_embedding): Embedding(59, 256)
#     (pos_embedding): Embedding(102, 256)
#     (layers): ModuleList(
#       (0): EncoderLayer(
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadAttentionLayer(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (positionwise_feedforward): PositionwiseFeedforwardLayer(
#           (fc_1): Linear(in_features=256, out_features=512, bias=True)
#           (fc_2): Linear(in_features=512, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (1): EncoderLayer(
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadAttentionLayer(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (positionwise_feedforward): PositionwiseFeedforwardLayer(
#           (fc_1): Linear(in_features=256, out_features=512, bias=True)
#           (fc_2): Linear(in_features=512, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (2): EncoderLayer(
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadAttentionLayer(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (positionwise_feedforward): PositionwiseFeedforwardLayer(
#           (fc_1): Linear(in_features=256, out_features=512, bias=True)
#           (fc_2): Linear(in_features=512, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): Decoder(
#     (tok_embedding): Embedding(59, 256)
#     (pos_embedding): Embedding(102, 256)
#     (layers): ModuleList(
#       (0): DecoderLayer(
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (enc_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadAttentionLayer(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (encoder_attention): MultiHeadAttentionLayer(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (positionwise_feedforward): PositionwiseFeedforwardLayer(
#           (fc_1): Linear(in_features=256, out_features=512, bias=True)
#           (fc_2): Linear(in_features=512, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (1): DecoderLayer(
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (enc_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadAttentionLayer(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (encoder_attention): MultiHeadAttentionLayer(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (positionwise_feedforward): PositionwiseFeedforwardLayer(
#           (fc_1): Linear(in_features=256, out_features=512, bias=True)
#           (fc_2): Linear(in_features=512, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (2): DecoderLayer(
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (enc_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadAttentionLayer(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (encoder_attention): MultiHeadAttentionLayer(
#           (fc_q): Linear(in_features=256, out_features=256, bias=True)
#           (fc_k): Linear(in_features=256, out_features=256, bias=True)
#           (fc_v): Linear(in_features=256, out_features=256, bias=True)
#           (fc_o): Linear(in_features=256, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (positionwise_feedforward): PositionwiseFeedforwardLayer(
#           (fc_1): Linear(in_features=256, out_features=512, bias=True)
#           (fc_2): Linear(in_features=512, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (fc_out): Linear(in_features=256, out_features=59, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )

# %%
test_trg = '/home/wei/Desktop/Similarity/chembl33_dataset/curriculum_learning/lev_5*ABpBAp_dataset/tvt/test.trg'
with open(test_trg, 'r') as file:
    contents = file.read()
    trg_smis = contents.split('\n')

test_src = '/home/wei/Desktop/Similarity/chembl33_dataset/curriculum_learning/lev_5*ABpBAp_dataset/tvt/test.src'
with open(test_src, 'r') as file:
    contents = file.read()
    src_smis = contents.split('\n')

# %% [markdown]
# ## generate SMILES using three decoders

# %%
src_smis[0]
# Out:
# 'CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccccc1'

# %%
tokenizer = vocabulary.SMILESTokenizer()
generated_smiles = multi_gen_test.get_sim_smiles_decoding(
    src_smis[0],
    SRC,
    TRG,
    model,
    device,
    max_length,
    10,
    1.2,  # Temperature for sampling (not relevant for this decoder)
    tokenizer,
    decoder_type=1,  # Standard beam search
    use_masking=True,
    prefix_length=0   # Specify where modifications start
)
generated_smiles
# Out:
# [('CN(CCCN1C(=O)c2ccccc2C1=O)Cc1ccccc1', -2.661444155643373),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccccc1', -3.2709101806673218),
#  ('CN(CCCN1C(=O)c2ccncc2C1=O)Cc1ccccc1', -3.3758833391663003),
#  ('CN(CCCN1C(=O)c2cccnc2C1=O)Cc1ccccc1', -3.7271298959598127),
#  ('CN(CCCN1C(=O)c2ncccc2C1=O)Cc1ccccc1', -3.9511488980758642),
#  ('CN(CCCCN1C(=O)c2ccccc2C1=O)Cc1ccccc1', -4.10260442714047),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)C', -4.543625919176854),
#  ('CN(CCCCN1C(=O)c2cnccc2C1=O)Cc1ccccc1', -4.563300376406794),
#  ('N(CCCN1C(=O)c2ccccc2C1=O)Cc1ccccc1', -4.784602154365757),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(OC)cc1', -4.8598453328297)]

# %%
generation_w_var = multi_gen_test.generation_with_variants(
    src_smis[0],
    SRC,
    TRG,
    model,
    device,
    max_length,
    10,
    1.2,
    tokenizer,
    variant_count=10,
    decoder_type=0,
    use_masking=True,
    prefix_length=0  # Specify the starting position for modifications
)
generation_w_var
# Out:
# [('n1ccc2c(c1)C(=O)N(CCCN(Cc1ccccc1)C)C2=O', -2.4927966390593976),
#  ('n1ccc2c(c1)C(=O)N(CCN1CCN(Cc3ccccc3)CC1)C2=O', -2.501044849660025),
#  ('n1ccc2c(c1)C(=O)N(CCN(Cc1ccccc1)C)C2=O', -2.7319841989934925),
#  ('c1ccc2c(c1)C(=O)N(CCCN(Cc1ccccc1)C)C2=O', -2.7319938549925653),
#  ('n1ccc2c(c1)C(=O)N(CCCN(Cc1ccc(F)cc1)C)C2=O', -2.734346100665184),
#  ('n1ccc2c(c1)C(=O)N(CCCN1CCN(c3ccccc3)CC1)C2=O', -2.7345800753879885),
#  ('n1ccc2c(c1)C(=O)N(CCN1CCN(Cc3ccccc3)CC1)C(=O)C2=O', -3.234783884001757),
    src_smis[0],
    SRC,
    TRG,
    model,
    device,
    max_length,
    10,
    2,
    tokenizer,  # User-provided tokenizer
    temperature=1.2,
    decoder_type=0,
    use_masking=True,
    prefix_length=0
)
generation_w_recur
# Out:
# Step 1/2: Processing 1 SMILES
# Step 2/2: Processing 10 SMILES
# [('CN(CCCN1C(=O)c2ccccc2C1=O)Cc1ccccc1', -2.661444227848265),
#  ('CN(CCCCN1C(=O)c2ccccc2C1=O)Cc1ccccc1', -2.698094561612762),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(OC)cc1', -2.8940761146750584),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(OC)c1', -2.8979744167264645),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(OC)c(OC)c1', -2.9030787910600213),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(C(F)(F)F)c1', -2.9082779233861893),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(OC)c1OC(=O)C', -2.9246568729969153),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(C(C)(C)OC(C)(C)C)c1',
#   -2.9313542669079617),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(OC)c1OC(=O)c1ccc(Cl)cc1',
#   -3.0051907483465166),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(OC)c1OC(=O)c1ccc(OC)cc1',
#   -3.0077205268268488),
#  ('CN(CCCN1C(=O)c2cc(OC)ccc2C1=O)Cc1ccccc1', -2.5532210136610027),
#  ('CN(CCCN1C(=O)c2ccccc2C1=O)Cc1ccc(O)c(OC)c1', -2.5573696317497867),
#  ('CN(CCCN1C(=O)c2ccccc2C1=O)Cc1ccc(OC)c(OC)c1', -2.562673704941964),
#  ('CN(CCCN1C(=O)c2ccccc2C1=O)Cc1ccc(OC)c(OC(F)(F)F)c1', -2.566219834463324),
#  ('CN(CCCN1C(=O)c2ccccc2C1=O)Cc1ccc(OC)c(OC(=O)c2ccccc2)c1',
#   -2.6060325896509897),
#  ('CN(CCCN1C(=O)c2ccccc2C1=O)Cc1ccc(OC)c(OC(=O)c2cc(OC)c(OC)cc2)c1',
#   -2.8526879143698047),
#  ('CN(CCCN1C(=O)c2ccccc2C1=O)Cc1ccc(OC)c(OC(=O)c2cc(OC)c(OC)c(OC)c2)c1',
#   -2.8679221065894853),
#  ('CN(CCCN1C(=O)c2ccccc2C1=O)Cc1ccc(OC)cc1', -3.5372663747788033),
#  ('CN(CCCCN1C(=O)c2ccccc2C1=O)Cc1ccc(Cl)cc1', -2.2141648790297945),
#  ('CN(CCCCN1C(=O)c2ccccc2C1=O)Cc1ccc(Cl)c(Cl)c1', -2.232067997136679),
#  ('CN(CCCCN1C(=O)c2ccccc2C1=O)Cc1ccc(Cl)c(C(F)(F)F)c1', -2.245614818060756),
#  ('CN(CCCCN1C(=O)c2ccccc2C1=O)Cc1ccc(Cl)c(C(=O)c2ccccc2)c1',
#   -2.316776334224027),
#  ('CN(CCCCN1C(=O)c2ccccc2C1=O)Cc1ccc(Cl)c(C(=O)N2CCN(C)CC2)c1',
#   -2.3395730005545086),
#  ('CN(CCCCN1C(=O)c2ccccc2C1=O)Cc1ccc(Cl)c(C(=O)N2CCN(c3ccccc3)CC2)c1',
#   -2.384251308592949),
#  ('CN(CCCCN1C(=O)c2ccccc2C1=O)Cc1ccc(Cl)c(C(=O)N2CCN(c3ccccc3)C[C@H]2C)c1',
#   -2.393302341625083),
#  ('CN(CCCCN1C(=O)c2ccccc2C1=O)Cc1ccc(Cl)c(C(=O)N2CCN(c3ccccc3)C(C)C2)c1',
#   -2.4307860600441806),
#  ('CN(CCCCN1C(=O)c2ccccc2C1=O)Cc1ccc(Cl)c(C(=O)N2CCN(c3ccccc3)C(=O)C2)c1',
#   -2.441371767219003),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(OC)c(OC(F)(F)F)c1', -2.828253251115089),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(OC)c(OC(=O)N(C)C)c1', -2.8299594562700436),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(OC)c(OC(=O)c2ccccc2)c1',
#   -2.830898430646613),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(OC)c(OC(=O)c2cc(OC)c(OC)cc2)c1',
#   -2.944027438771324),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(OC)c(OC(=O)c2cc(OC(F)(F)F)ccc2)c1',
#   -2.948877932181198),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(OC)c(OC(=O)c2cc(OC)c(OC)c(OC)c2)c1',
#   -2.9492040227498704),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(OC)c(OC(=O)c2cc(OC)c(OC(F)(F)F)cc2)c1',
#   -2.950427684121317),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(OC)c(OC(=O)c2cc(OC)c(OC(F)(F)F)cc2F)c1',
#   -2.9508018328568366),
#  ('CN(CCCCN1C(=O)c2ccccc2C1=O)Cc1ccc(O)c(OC)c1', -2.6160769721118657),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(OC)c1OC', -2.640358477635649),
#  ('CN(CCCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(OC)c1OC', -2.6511810121779535),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(OC)c1OCc1ccccc1', -2.941295311723346),
#  ('CN(CCCN1C(=O)c2ccccc2C1=O)Cc1ccc(O)cc1', -3.5581376796211694),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(OC)c1OCc1ccc(O)cc1',
#   -3.588742344252901),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(OC)c1OCc1ccc(O)c(OC)c1',
#   -3.5895933188806484),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(OC)c1OC(=O)c1ccccc1C(F)(F)F',
#   -3.5926291334232743),
#  ('CN(CCCCN1C(=O)c2ccccc2C1=O)Cc1ccc(OC)c(OC)c1', -2.5360344714295042),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(OC)c(OC)c1OC', -2.5479496923739706),
#  ('CN(CCCCN1C(=O)c2cnccc2C1=O)Cc1ccc(OC)c(OC)c1OC', -2.55329906734612),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(OC)c(OC)c1OC(=O)C', -2.6839040501233873),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(OC)c(OC)c1OC(F)(F)F', -2.6840909279239926),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(OC)c(OC)c1OC(=O)c1ccccc1',
#   -3.4270640392894474),
#  ('CN(CCCN1C(=O)c2ccncc2C1=O)Cc1ccc(OC)c(OC)c1', -3.456549144578903),
#  ('CN(CCCCN1C(=O)c2cnccc2C1=O)Cc1ccc(OC)c(OC)c1', -3.462743210246966),
#  ('CN(CCCN1C(=O)c2cccnc2C1=O)Cc1ccc(OC)c(OC)c1', -3.5346948756824457),
#  ('CN(CCCN1C(=O)c2ccccc2C1=O)Cc1ccc(O)c(C(F)(F)F)c1', -3.099243182132693),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(C(C)(OC)C)c1', -3.1004906506482173),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(C(C)(O)C(F)(F)F)c1',
#   -3.1041684126103894),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(C(C)(OC)C)c1OC(C)=O',
#   -3.1042947824416443),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(C(C)(OC)C)c1OC(C)(C)C',
#   -3.130574988206229),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)cc1', -3.342651506462234),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(C(C)(OC)C)c1OC(=O)c1ccccc1',
#   -3.382832513722017),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(C(C)(OC)C)c1OCc1ccc(O)c(C(F)(F)F)c1',
#   -3.3836662269486),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(C(C)(OC)C)c1OC(=O)c1ccc(O)c(C(F)(F)F)c1',
#   -3.3840133469565563),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(C(C)(OC)C)c1OC(=O)c1ccc(O)c(C(C)(OC)C)c1',
#   -3.384173934763113),
#  ('CN(CCCN1C(=O)c2ccccc2C1=O)Cc1ccc(O)c(OC)c1OC(=O)C', -2.6628753608617406),
#  ('CN(CCCCN1C(=O)c2ccccc2C1=O)Cc1ccc(O)c(OC)c1OC(=O)C', -2.6645335055302737),
#  ('CN(CCCN1C(=O)c2ccccc2C1=O)Cc1ccc(O)c(OC)c1OC(=O)c1ccccc1',
#   -3.0302307323359834),
#  ('CN(CCCN1C(=O)c2ccccc2C1=O)Cc1ccc(O)c(OC)c1O', -3.486332850586055),
#  ('CN(CCCN1C(=O)c2cccnc2C1=O)Cc1ccc(O)c(OC)c1OC(=O)C', -3.5499254839367818),
#  ('CN(CCCN1C(=O)c2ncccc2C1=O)Cc1ccc(O)c(OC)c1OC(=O)C', -3.6332993746489612),
#  ('CN(CCCN1C(=O)c2ccccc2C1=O)Cc1ccc(O)c(OC)c1OC(=O)c1ccc(O)cc1',
#   -3.670583033917561),
#  ('CN(CCCN1C(=O)c2ccncc2C1=O)Cc1ccc(O)c(OC)c1OC(=O)C', -3.742380018765395),
#  ('CN(CCCN1C(=O)c2ccccc2C1=O)Cc1ccc(O)c(C(C)(C)OC(C)(C)C)c1',
#   -3.236652998848549),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(C(C)(C)OC(C)(C)C)c1Cl',
#   -3.2366531180578457),
#  ('CN(CCCN1C(=O)c2ccccc2C1=O)Cc1ccc(O)c(C(C)(C)O)c1', -3.298451510680831),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(C(C)(C)OC(C)(C)C)c1F',
#   -3.3259291064879037),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(C(C)(C)OC(C)(C)C)c1C[C@@]N',
#   -3.3646155606945487),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(C(C)(C)OC(C)(C)C)c1C(F)(F)F',
#   -3.3751913270577627),
#  ('CN(CCCN1C(=O)c2ccccc2C1=O)Cc1ccc(O)c(C(C)(C)C)c1', -3.4730862948506553),
#  ('CN(CCCN1C(=O)c2cccnc2C1=O)Cc1ccc(O)c(C(C)(C)OC(C)(C)C)c1',
#   -3.4813923693905298),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(C(C)(C)OC(C)(C)C)c1C',
#   -3.556288221766712),
#  ('CN(CCCN1C(=O)c2ccccc2C1=O)Cc1ccc(O)c(OC)c1OC(=O)c1ccc(Cl)cc1',
#   -2.900949320981683),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(OC)c1OC(=O)c1ccc(O)c(OC)c1',
#   -2.9554974803504366),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(OC)c1OC(=O)c1ccc(OC)c(OC)c1',
#   -2.9816990868514424),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(OC)c1OC(=O)c1ccc(OC)cc1OC(=O)C',
#   -3.567533734735882),
#  ('CN(CCCN1C(=O)c2cccnc2C1=O)Cc1ccc(O)c(OC)c1OC(=O)c1ccc(Cl)cc1',
#   -3.6133425350021966),
#  ('CN(CCCN1C(=O)c2ncccc2C1=O)Cc1ccc(O)c(OC)c1OC(=O)c1ccc(Cl)cc1',
#   -3.6663639612627876),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(OC)c1O', -3.6961002627397033),
#  ('CN(CCCN1C(=O)c2ccccc2C1=O)Cc1ccc(O)c(OC)c1OC(=O)c1ccc(OC)cc1',
#   -2.995411866110247),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(OC)c1OC(=O)c1ccccc1',
#   -3.7012739030551276),
#  ('CN(CCCN1C(=O)c2cccnc2C1=O)Cc1ccc(O)c(OC)c1OC(=O)c1ccc(OC)cc1',
#   -3.7306671804633815),
#  ('CN(CCCN1C(=O)c2cnccc2C1=O)Cc1ccc(O)c(OC)c1OC(=O)c1ccc(OC)c(O)c1',
#   -3.734430515534966)]
